# %%
import pandas as pd
df = pd.read_csv('C:/Users/udoha/Desktop/lagossNigeriaData.csv')
pd.set_option('display.max_columns', None)
df
# Out:
#               name   datetime  tempmax  tempmin  temp  feelslikemax  \
# 0   lagos, Nigeria   2/1/2023     34.0     25.0  28.4          40.6
# 1   lagos, Nigeria   2/2/2023     34.0     25.0  29.0          42.0
# 2   lagos, Nigeria   2/3/2023     34.1     25.0  29.2          42.0
# 3   lagos, Nigeria   2/4/2023     34.0     25.0  29.1          42.0
# 4   lagos, Nigeria   2/5/2023     35.0     26.9  29.5          42.0
# 5   lagos, Nigeria   2/6/2023     34.0     26.0  29.3          42.0
# 6   lagos, Nigeria   2/7/2023     34.0     25.0  28.8          40.1
# 7   lagos, Nigeria   2/8/2023     34.5     25.0  28.9          42.6
# 8   lagos, Nigeria   2/9/2023     33.5     25.0  29.1          40.6
# 9   lagos, Nigeria  2/10/2023     36.5     25.9  29.4          41.9
# 10  lagos, Nigeria  2/11/2023     35.0     26.0  29.5          43.3
# 11  lagos, Nigeria  2/12/2023     35.1     25.9  29.4          43.3
# 12  lagos, Nigeria  2/13/2023     34.5     26.0  29.4          42.7
# ...

# %%
df['tempmax'].max()
# Out:
# 36.5

# %%
df['temp'].max()
# Out:
# 29.8

# %%
df['datetime'][df['conditions']=='partially cloudy']
# Out:
# Series([], Name: datetime, dtype: object)

# %%
df['moonphase'].mean()
# Out:
# 0.629

# %% [markdown]
# # Days with rainfall
# ## Having gone through the csv file, it was observed that the days that there were rain was released below

# %%
df['datetime'][df['preciptype']=='rain']
# Out:
# 1      2/2/2023
# 2      2/3/2023
# 3      2/4/2023
# 4      2/5/2023
# 5      2/6/2023
# 6      2/7/2023
# 7      2/8/2023
# 8      2/9/2023
# 9     2/10/2023
# 10    2/11/2023
# 11    2/12/2023
# 12    2/13/2023
# Name: datetime, dtype: object
